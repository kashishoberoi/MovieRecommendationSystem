# %%
# Import libraries
import numpy as np
import pandas as pd

# Reading ratings file
ratings = pd.read_csv('./../data/ratings.csv')

# Reading movies file
movies = pd.read_csv('./../data/movies.csv')

# %%
ratings.head().iloc[:100000]
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.sample(frac = 0.0001)
# Out:
#           userId  movieId  rating   timestamp
# 1952200    12982     3897     3.5  1064601879
# 9237932    60215    51662     4.5  1349134204
# 13474103   87160     1228     5.0  1036428464
# 2017363    13435     1217     5.0   962821134
# 298386      2058     2729     3.5  1142872792
# 2352187    15664     2000     3.5  1141603420
# 11458226   74304     3638     2.0   959232487
# 17640856  114350     1617     4.5  1079046643
# 7113778    46112    60069     3.5  1227427893
# 21101200  137150   102445     4.5  1478487768
# 261216      1838     1580     3.5  1232102255
# 19121825  124037     1198     4.0  1481926800
# 18035430  116868     2076     4.0  1010013704
# 9455232    61487      198     3.0   837190470
# 19902682  129407    45447     3.5  1462707705
# 17610659  114166     1573     1.0  1186595866
# 13926022   90275     2081     5.0   945928676
# 6934926    44995     2067     5.0   990547915
# 6465150    41908    91630     3.5  1365883724
# ...

# %%
userid_movietitle_matrix = ratings.sample(frac = 0.001).pivot_table(index = 'userId', columns = 'movieId', values = 'rating')

# %%
userid_movietitle_matrix
# Out:
# movieId  1       2       3       5       6       10      11      16      \
# userId
# 19          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 59          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 61          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 255         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 345         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 426         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 458         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 460         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 493         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 613         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 699         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 714         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
movie_correlations = userid_movietitle_matrix.corr(method = 'pearson')
